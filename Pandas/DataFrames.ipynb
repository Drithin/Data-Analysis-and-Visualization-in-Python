# %%
import numpy as np

from pandas import Series,DataFrame
import pandas as pd

# %%
#Grab data from internet(Something like Wikipedia and Play around with that data)

import webbrowser

web = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'

webbrowser.open(web)
# Out:
# True

# %%
nfl_frame = pd.read_csv('/Users/DrithnChakrav/Desktop/CS/DataSets/irisdataset.csv')

# %%
nfl_frame
# Out:
#      s.l  s.w  p.l  p.w           class
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 5    4.6  3.4  1.4  0.3     Iris-setosa
# 6    5.0  3.4  1.5  0.2     Iris-setosa
# 7    4.4  2.9  1.4  0.2     Iris-setosa
# 8    4.9  3.1  1.5  0.1     Iris-setosa
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 10   4.8  3.4  1.6  0.2     Iris-setosa
# 11   4.8  3.0  1.4  0.1     Iris-setosa
# 12   4.3  3.0  1.1  0.1     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# 16   5.1  3.5  1.4  0.3     Iris-setosa
# 17   5.7  3.8  1.7  0.3     Iris-setosa
# 18   5.1  3.8  1.5  0.3     Iris-setosa
# 19   5.4  3.4  1.7  0.2     Iris-setosa
# 20   5.1  3.7  1.5  0.4     Iris-setosa
# 21   4.6  3.6  1.0  0.2     Iris-setosa
# ...

# %%
nfl_frame.head()
# Out:
#    s.l  s.w  p.l  p.w        class
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
nfl_frame.columns
# Out:
# Index(['s.l', 's.w', 'p.l', 'p.w', 'class'], dtype='object')

# %%
DataFrame(nfl_frame, columns=['s.l','s.w'])
# Out:
#      s.l  s.w
# 0    4.9  3.0
# 1    4.7  3.2
# 2    4.6  3.1
# 3    5.0  3.6
# 4    5.4  3.9
# 5    4.6  3.4
# 6    5.0  3.4
# 7    4.4  2.9
# 8    4.9  3.1
# 9    5.4  3.7
# 10   4.8  3.4
# 11   4.8  3.0
# 12   4.3  3.0
# 13   5.8  4.0
# 14   5.7  4.4
# 15   5.4  3.9
# 16   5.1  3.5
# 17   5.7  3.8
# 18   5.1  3.8
# 19   5.4  3.4
# 20   5.1  3.7
# 21   4.6  3.6
# 22   5.1  3.3
# 23   4.8  3.4
# 24   5.0  3.0
# 25   5.0  3.4
# 26   5.2  3.5
# 27   5.2  3.4
# 28   4.7  3.2
# 29   4.8  3.1
# ..   ...  ...
# 119  6.9  3.2
# 120  5.6  2.8
# 121  7.7  2.8
# 122  6.3  2.7
# 123  6.7  3.3
# 124  7.2  3.2
# 125  6.2  2.8
# 126  6.1  3.0
# 127  6.4  2.8
# 128  7.2  3.0
# 129  7.4  2.8
# 130  7.9  3.8
# 131  6.4  2.8
# 132  6.3  2.8
# 133  6.1  2.6
# 134  7.7  3.0
# 135  6.3  3.4
# 136  6.4  3.1
# 137  6.0  3.0
# 138  6.9  3.1
# 139  6.7  3.1
# 140  6.9  3.1
# 141  5.8  2.7
# 142  6.8  3.2
# 143  6.7  3.3
# 144  6.7  3.0
# 145  6.3  2.5
# 146  6.5  3.0
# 147  6.2  3.4
# 148  5.9  3.0
#
# ...

# %%
nfl_frame['s.l']
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
# 5      4.6
# 6      5.0
# 7      4.4
# 8      4.9
# 9      5.4
# 10     4.8
# 11     4.8
# 12     4.3
# 13     5.8
# 14     5.7
# 15     5.4
# 16     5.1
# 17     5.7
# 18     5.1
# 19     5.4
# 20     5.1
# 21     4.6
# 22     5.1
# 23     4.8
# 24     5.0
# 25     5.0
# 26     5.2
# 27     5.2
# 28     4.7
# 29     4.8
#       ...
# 119    6.9
# 120    5.6
# 121    7.7
# 122    6.3
# 123    6.7
# 124    7.2
# 125    6.2
# 126    6.1
# 127    6.4
# 128    7.2
# 129    7.4
# 130    7.9
# 131    6.4
# 132    6.3
# 133    6.1
# 134    7.7
# 135    6.3
# 136    6.4
# 137    6.0
# 138    6.9
# 139    6.7
# 140    6.9
# 141    5.8
# 142    6.8
# 143    6.7
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: s.l, dtype: float64

# %%
nfl_frame.ix[3] #indexing, 4th row
# Out:
# s.l                5
# s.w              3.6
# p.l              1.4
# p.w              0.2
# class    Iris-setosa
# Name: 3, dtype: object

# %%
nfl_frame['Test Col'] = 'This is Row'

# %%
nfl_frame.head()
# Out:
#    s.l  s.w  p.l  p.w        class     Test Col
# 0  4.9  3.0  1.4  0.2  Iris-setosa  This is Row
# 1  4.7  3.2  1.3  0.2  Iris-setosa  This is Row
# 2  4.6  3.1  1.5  0.2  Iris-setosa  This is Row
# 3  5.0  3.6  1.4  0.2  Iris-setosa  This is Row
# 4  5.4  3.9  1.7  0.4  Iris-setosa  This is Row

# %%
del nfl_frame['Test Col']

# %%
nfl_frame.head()
# Out:
#    s.l  s.w  p.l  p.w       class
# 0  4.9  3.0  1.4  0.2         NaN
# 1  4.7  3.2  1.3  0.2         NaN
# 2  4.6  3.1  1.5  0.2  Test Row 1
# 3  5.0  3.6  1.4  0.2         NaN
# 4  5.4  3.9  1.7  0.4  Test Row 2

# %%
#testRows = Series(['Test Row 1', 'Test Row 2'], index = [2,4]) #Changes value of specific rows

#nfl_frame['class']=testRows

# %%
#nfl_frame.head()
# Out:
#    s.l  s.w  p.l  p.w       class
# 0  4.9  3.0  1.4  0.2         NaN
# 1  4.7  3.2  1.3  0.2         NaN
# 2  4.6  3.1  1.5  0.2  Test Row 1
# 3  5.0  3.6  1.4  0.2         NaN
# 4  5.4  3.9  1.7  0.4  Test Row 2

# %%
#DataFrames can be constructed many ways. Another way is from a dictionary of equal length lists
data = {'City':['SF','LA','SD'], 'Population':[100000,200000,300000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'SD'], 'Population': [100000, 200000, 300000]}

# %%
cityData = DataFrame(data)

# %%
cityData
# Out:
#   City  Population
# 0   SF      100000
# 1   LA      200000
# 2   SD      300000
