# %%
import pandas as pd

# %%
xlsfile = pd.ExcelFile('/Users/DrithnChakrav/Desktop/Time-Sheets/Drithin_November_ TImesheets.xlsx')

# %%
dframe = xlsfile.parse() #We parse the excel file and assign to a data frame, we can give specific sheets inside excel 
#in the parse() bracket to parse into a data frame

# %%
dframe
# Out:
#     Unnamed: 0                                       INSTRUCTIONS
# 0          NaN                                                NaN
# 1          NaN  Timesheets and receipts must be completed and ...
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5          NaN       Only enter data into the light YELLOW cells.
# 6          NaN                                                NaN
# 7          NaN  Only enter your name, time period, client name...
# 8          NaN                                                NaN
# 9          NaN  Time is entered in hours.  Do not enter anythi...
# 10         NaN                                                NaN
# 11         NaN  Use the Notes sections for general notes and c...
# 12         NaN                                                NaN
# ...
