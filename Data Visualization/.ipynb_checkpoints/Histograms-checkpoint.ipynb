# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats librayr from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
#Create a random dataset

dataset1 = randn(100)

plt.hist(dataset1)
# Out:
# (array([  1.,   3.,   8.,  17.,  19.,  18.,  18.,   9.,   5.,   2.]),
#  array([-2.83922131, -2.28095886, -1.72269641, -1.16443396, -0.6061715 ,
#         -0.04790905,  0.5103534 ,  1.06861585,  1.62687831,  2.18514076,
#          2.74340321]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

plt.hist(dataset2,color='indianred')
# Out:
# (array([  2.,   3.,  12.,  14.,  22.,  12.,   8.,   5.,   1.,   1.]),
#  array([-2.5117315 , -1.89893613, -1.28614075, -0.67334538, -0.06055   ,
#          0.55224537,  1.16504074,  1.77783612,  2.39063149,  3.00342687,
#          3.61622224]),
#  <a list of 10 Patch objects>)

# %%
#We can used normed to plot on same plot

plt.hist(dataset1,normed=True,alpha=0.5,bins=20)
plt.hist(dataset2,normed=True,color='indianred',alpha=0.5,bins=20)
# Out:
# (array([ 0.08159331,  0.        ,  0.        ,  0.12238996,  0.16318661,
#          0.32637322,  0.16318661,  0.40796653,  0.57115314,  0.32637322,
#          0.20398326,  0.28557657,  0.12238996,  0.20398326,  0.12238996,
#          0.08159331,  0.        ,  0.04079665,  0.        ,  0.04079665]),
#  array([-2.5117315 , -2.20533381, -1.89893613, -1.59253844, -1.28614075,
#         -0.97974307, -0.67334538, -0.36694769, -0.06055   ,  0.24584768,
#          0.55224537,  0.85864306,  1.16504074,  1.47143843,  1.77783612,
#          2.08423381,  2.39063149,  2.69702918,  3.00342687,  3.30982455,
#          3.61622224]),
#  <a list of 20 Patch objects>)

# %%
#Make two normal distribution datasets

data1 = randn(1000)
data2 = randn(1000)

sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')
